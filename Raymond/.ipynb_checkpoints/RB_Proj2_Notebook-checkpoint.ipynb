# %%
from bs4 import BeautifulSoup as bs
import pandas as pd
from sqlalchemy import create_engine
import requests
import os
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
from selenium import webdriver

# %%
options = webdriver.ChromeOptions()
options.add_argument("start-maximized")
options.add_argument('--disable-blink-features=AutomationControlled')
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, options=options)
# Out:
# [WDM] - Downloading: 100%|█████████████████| 8.61M/8.61M [00:00<00:00, 23.2MB/s]

# %%
# Dice.com URL to scrape
url = 'https://dice.com'

# %%
browser.visit(url)

# %%
html = browser.html
html[0:500]
# Out:
# '<html lang="en" class=""><head>\n        <meta charset="utf-8">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge">\n        <meta name="viewport" content="width=device-width, initial-scale=1">\n        <meta name="google-play-app" content="app-id=com.dice.app.jobs">\n        <meta name="apple-itunes-app" content="app-id=794201100, affiliate-data=, app-argument=">\n        <link rel="apple-touch-icon" sizes="57x57" href="/webfiles/1670950067040/favicon/dice/apple-touch-icon-57x57.png">\n    '

# %%
response = requests.get(url)

# %%
soup= BeautifulSoup(browser.html, "html.parser")
print(soup.prettify())
# Out:
# <html class="" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="app-id=com.dice.app.jobs" name="google-play-app"/>
#   <meta content="app-id=794201100, affiliate-data=, app-argument=" name="apple-itunes-app"/>
#   <link href="/webfiles/1670950067040/favicon/dice/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
#   <link href="/webfiles/1670950067040/favicon/dice/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
#   <link href="/webfiles/1670950067040/favicon/dice/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#   <link href="/webfiles/1670950067040/favicon/dice/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="/webfiles/1670950067040/favicon/dice/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="/webfiles/1670950067040/favicon/dice/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="/webfiles/1670950067040/favicon/dice/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
#   <link href="/webfiles/1670950067040/favicon/dice/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="/webfiles/1670950067040/favicon/dice/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/webfiles/1670950067040/favicon/dice/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/webfiles/1670950067040/favicon/dice/favicon-194x194.png" rel="icon" sizes="194x194" type="image/png"/>
#   <link href="/webfiles/1670950067040/favicon/dice/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
#   <link href="/webfiles/1670950067040/favicon/dice/android-chrome-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
#   <link href="/webfiles/1670950067040/favicon/dice/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="https://www.dice.com/manifest.json" rel="manifest"/>
#   <link color="#5bbad5" href="/webfiles/1670950067040/favicon/dice/safari-pinned-tab.svg" rel="mask-icon"/>
#   <link href="/webfiles/1670950067040/favicon/dice/favicon.ico" rel="shortcut icon"/>
#   <meta content="Dice" name="apple-mobile-web-app-title"/>
#   <meta content="Dice" name="application-name"/>
#   <meta content="#cc0000" name="msapplication-TileColor"/>
#   <meta content="/webfiles/1670950067040/favicon/dice/mstile-144x144.png" name="msapplication-TileImage"/>
#   <meta content="/browserconfig.xml" name="msapplication-config"/>
#   <meta content="#cc0000" name="theme-color"/>
#   <!-- include funnel envy before GTM based on optimize implementation without component -->
#   <!-- end funnel envy include -->
#   <!-- include optimize tesing before GTM based on optimize implementation without component -->
#   <!-- end optimize testing include -->
#   <!-- include optimize or funnel envy based on component before GTM -->
#   <!-- end of include -->
#   <script async="" src="//bat.bing.com/bat.js">
#   </script>
#   <script async="" src="https://connect.facebook.net/signals/config/412179360593168?v=2.9.90&amp;r=stable">
#   </script>
#   <script async="" src="https://connect.facebook.net/en_US/fbevents.js">
#   </script>
#   <script async="" src="https://www.redditstatic.com/ads/pixel.js">
#   </script>
#   <script async="" src="https://snap.licdn.com/li.lms-analytics/insight.min.js" type="text/javascript">
#   </script>
#   <script async="" src="https://bat.bing.com/bat.js" type="text/javascript">
#   </script>
#   <script async="" src="https://www.google-analytics.com/gtm/optimize-dyn.js?id=GTM-WL6BH3V&amp;cid=1181893880.1671315031&amp;cb=0.28388289034095804" type="text/javascript">
#   </script>
#   <script async="" src="//munchkin.marketo.net/162/munchkin.js" type="text/javascript">
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-QEM1ZGKRC2&amp;l=dataLayer&amp;cx=c" type="text/javascript">
#   </script>
#   <script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript">
#   </script>
#   <script async="" src="https://cdn.branch.io/branch-latest.min.js">
#   </script>
#   <script async="" gtm="GTM-WLPMJGK" src="https://www.googleoptimize.com/optimize.js?id=GTM-WL6BH3V" type="text/javascript">
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-WLPMJGK">
#   </script>
#   <script type="text/javascript">
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#                     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#                 j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#                 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer','GTM-WLPMJGK');
#   </script>
#   <link href="https://d1l8sqvw5snhqo.cloudfront.net/css/3.3.4/dice-bs4-theme.min.css" rel="stylesheet"/>
#   <link crossorigin="anonymous" href="//maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" integrity="sha384-wvfXpqpZZVQGK6TAh5PVlGOfQNHSoD2xbE+QkPxCAFlNEevoEH3Sl0sibVcOQVnN" rel="stylesheet"/>
#   <link href="/webfiles/1670950067040/css/dhi/smart-app-banner.css" rel="stylesheet" type="text/css"/>
#   <link href="/webfiles/1670950067040/css/dice/dice-layout.css" rel="stylesheet" type="text/css"/>
#   <!-- include funnel envy in Head based on optimize implementation without component -->
#   <!-- end funnel envy include -->
#   <!-- include optimize tesing in head based on optimize implementation without component -->
#   <!-- end optimize testing include -->
#   <style type="text/css">
#    /*<![CDATA[*/
#
#         .dice-subnav .showSearchMagnifier {
#
#         }
#         .dice-subnav .magnifierSize {
#             font-size: 24px;
#         }
#         .dice-subnav .centerContent {
#             height: 46px;
#             background: #FFFFFF;
#             display:flex;
#             justify-content: center;
#             margin: .5rem 0 .5rem 0;
#         }
#         .dice-subnav .menu-icon::before {
#             color: #000000;
#             font-weight: 700;
#         }
#         .dice-subnav .hideSearchMagnifier {
#             display: none
#         }
#         .dice-subnav .hideSearchBox {
#             display: none;
#         }
#         .dice-subnav .hideCategoryList {
#             display: none;
#         }
#         .dice-subnav .row {
#             border-bottom: 1px solid #D4D2CE;
#             min-height: 56px;
#             align-content: center;
#         }
#         .dice-subnav .line-label {
#             font-weight: 700;
#             font-size: 14px;
#             letter-spacing: 0.02em;
#             text-transform: uppercase;
#             color: #28494F;
#         }
#         .dice-subnav .line-label:hover {
#             text-decoration: underline;
#         }
#         .dice-subnav .navbar-collapse {
#             min-height: 56px;
#             padding-top: 0;
#             margin-top: 0;
#             border-top: none;
#             transition: none;
#         }
#         .dice-subnav .navbar-toggler[aria-expanded="true"]>span.icon-arrow-67 {
#             display: none;
#         }
#         .dice-subnav .navbar-toggler[aria-expanded="false"]>span.icon-arrow-67 {
#             display: inline-block;
#             font-size: 14px;
#             font-weight: 700;
#         }
#         .dice-subnav .navbar-toggler[aria-expanded="true"]>span.icon-arrow-68 {
#             display: inline-block;
#             font-size: 14px;
#             font-weight: 700;
#         }
#         .dice-subnav .navbar-toggler[aria-expanded="false"]>span.icon-arrow-68 {
#             display:  none;
#         }
#         .dice-subnav ul.navbar-nav {
#             margin-left: 31px;
#         }
#         .dice-subnav nav.navbar li.nav-item:hover {
#             text-decoration: underline;
#             color: #123B5A;
#         }
#         .dice-subnav nav.navbar li.nav-item {
#             padding-top: 16px;
#         }
#         .dice-subnav nav.navbar li {
#             display: block;
#             position: relative;
#         }
#         .dice-subnav .nav-item a {
#             font-size: 14px;
#             color: #2B2927;
#             margin-right: 23px;
#         }
#         .dice-subnav  .nav-item a.category-selected{
#             text-decoration: underline;
#             font-weight: 700;
#             color: #071927;
#         }
#         .dice-subnav hr {
#             border-top: 1px solid #D4D2CE;
#             width: 500%;
#             margin-left: -100px;
#             margin-bottom: 0;
#         }
#         @media(min-width: 992px) {
#             .dice-subnav .localAlignment {
#                 align-items: center;
#             }
#             .dice-subnav .line-label {
#                 margin-left: 24px;
#                 padding-top: 4px;
#             }
#             .dice-subnav .line-label:hover {
#                 text-decoration: none;
#             }
#             .dice-subnav .navbar {
#                 padding: 0 1rem;
#             }
#             .dice-subnav .navbar-collapse {
#                 min-height: 64px;
#                 padding-top: 0;
#                 padding-bottom: 0;
#                 margin-top: 0;
#                 border-top: none;
#             }
#             .dice-subnav nav.navbar li.nav-item {
#                 padding-top: 0;
#             }
#             .dice-subnav hr {
#                 display: none;
#             }
#         }
#
# /*]]>*/
#   </style>
#   <link href="/webfiles/1670950067040/css/dice/career-advice-layout.css" rel="stylesheet" type="text/css"/>
#   <style type="text/css">
#    /*<![CDATA[*/
#
#         .dice-header {
#             border-bottom: 1px solid #000;
#             background-color: #333;
#             min-height: 60px;
#         }
#         .dice-header .dice-logo {
#             padding-left: 20px!important;
#         }
#         .dice-header .diceLogoSuppressedSpacing {
#             padding-left: 20px!important;
#         }
#         /*button class="navbar-toggler*/
#         .dice-header button.navbar-toggler {
#             padding-right: 28px;
#         }
#         .dice-header a.dropdown-toggle, .dice-header a.nav-item  {
#             color: #fff;
#             font-weight: 400;
#         }
#         .dice-header nav.navbar a.nav-item,.dice-header nav.navbar a.nav-link{
#             padding: 10px 20px 10px 20px;
#             display: block;
#         }
#         .dice-header nav.navbar a.nav-item:hover {
#             text-decoration: none;
#         }
#         .dice-header ul.navbar-nav {
#             min-height: 60px;
#         }
#         .dice-header nav.navbar li.nav-item:hover {
#             background-color: #4d4d4d;
#         }
#         .dice-header nav.navbar li {
#             display: block;
#             position: relative;
#         }
#         .dice-header nav.navbar {
#             padding: 0;
#         }
#         .navbar-collapse {
#             padding-top: 14px;
#             padding-bottom: 20px;
#             margin-top: 5px;
#             border-top: #090909 1px solid;
#         }
#         .dice-header ul#main-menu li.menu-item a:hover {
#             color: #fff;
#             background-color: #4d4d4d;
#         }
#         .dice-header div.dropdown-menu {
#             background-color: #757575;
#             color: #fff;
#             border: 0;
#             border-radius: 0;
#             margin-top: 1px;
#             padding: 0;
#             min-width: max-content;
#         }
#         .dice-header .dropdown-item:hover, .dice-header .dropdown-item:active, .dice-header .dropdown-item:focus {
#             background-color: #4d4d4d;
#             color: #fff;
#         }
#         .dice-header .dropdown-item {
#             color: #fff;
#             font-weight: 400;
#             font-size: 14px;
#             padding-top: 14px;
#             padding-bottom: 12px;
#             padding-left: 1.5rem;
#             padding-right: 1.5rem;
#         }
#         .dice-header .dropdown-item:first-of-type, .dice-header .dropdown-item:last-of-type {
#             margin-top: 0;
#             margin-bottom: 0;
#         }
#
#         .dice-header .dropdown-toggle::after {
#             display: none;
#             border: 0;
#         }
#         .dice-header .menu-toggle{
#             display: inline-block;
#             font-size: 1em;
#             margin-left: 2px;
#         }
#         .dice-header li.show .menu-toggle .menu-active, .dice-header li .menu-toggle .menu-inactive  {
#             display: none;
#         }
#         .dice-header li .menu-toggle .menu-active, .dice-header li.show .menu-toggle .menu-inactive {
#             display: inline;
#         }
#         .dice-header .menu-icon {
#             display: inline-block;
#             font-size: 1.2rem;
#             margin-right: 5px;
#             vertical-align: -7%;
#             color: #fff;
#         }
#         .dice-header .dropdown-menu .menu-icon {
#             font-size: 1rem;
#         }
#         .dice-header .dropdown .dropdown-menu {
#             -webkit-transition: max-height 400ms ease; /* Safari and Chrome */
#             -moz-transition: max-height 400ms ease; /* Firefox */
#             -ms-transition: max-height 400ms ease; /* IE 9 */
#             -o-transition: max-height 400ms ease; /* Opera */
#             transition: max-height 400ms ease;
#             max-height: 0;
#             display: none;
#             overflow: hidden;
#         }
#         .dice-header .dropdown .dropdown-menu.show {
#             display: block;
#             -webkit-transition: max-height 700ms ease; /* Safari and Chrome */
#             -moz-transition: max-height 700ms ease; /* Firefox */
#             -ms-transition: max-height 700ms ease; /* IE 9 */
#             -o-transition: max-height 700ms ease; /* Opera */
#             transition: max-height 700ms ease;
#             max-height: 300px;
#         }
#         hr.menu-sep {
#             display: block;
#             height: 1px;
#             border: 0;
#             border-top: 1px solid #999;
#             margin: .25rem 0;
#             padding: 0;
#         }
#         .dice-header .navbar .message-icon {
#             display: inline-block;
#             background-repeat: no-repeat;
#             background-position: center;
#             width: 32px;
#             height: 32px;
#             vertical-align: middle;
#         }
#         .dice-header .navbar .message-icon .unread-count {
#             border-radius: 9px;
#             height: 17px;
#             min-width: 17px;
#             color: white;
#             font-size: 14px;
#             font-weight: normal;
#             background-color: #cc0000;
#             padding-left: 14%;
#             padding-right: 14%;
#             position: relative;
#             right: 6px;
#             line-height: 1.3;
#         }
#         .dice-header span.newItemIcon {
#             color: white;
#             font-weight: 400;
#             display: inline-block;
#             border-radius: 3px;
#             background-color: #4C842E;
#             font-size: 12px;
#             line-height: 1;
#             padding: 3px 5px;
#             text-transform: uppercase;
#             position: relative;
#             white-space: nowrap;
#          }
#         .dice-header .message-icon-div {
#             margin: 6px 6px 0 4px;
#         }
#
#         @media(min-width: 992px) {
#             .dice-header .navbar-collapse {
#                 padding-top: 0;
#                 padding-bottom: 0;
#                 margin-top: 0;
#                 border-top: 0;
#             }
#             .dice-header nav.navbar a.nav-item,.dice-header nav.navbar a.nav-link{
#                 padding: 20px;
#                 display: block;
#             }
#             .dice-header .menu-icon {
#                 margin-top: -10%;
#                 margin-bottom: -5%;
#             }
#             .dice-header .dropdown-item {
#                 padding-top: 10px;
#                 padding-bottom: 10px;
#                 padding-left: 24px;
#                 padding-right: 30px;
#             }
#             .dice-header .dice-logo {
#                 padding-left: 32px!important;
#             }
#             .dice-header .diceLogoSuppressedSpacing {
#                 padding-left: 20px!important;
#             }
#             .dice-header li.dropdown:last-of-type {
#                 margin-right: 30px;
#             }
#             .dice-header ul.menu-right div.dropdown-menu {
#                 right: 0;
#                 left: auto;
#             }
#             .dice-header ul.menu-left>li>a>span.menu-icon {
#                 display: none;
#             }
#             hr.menu-sep {
#                 display: none;
#             }
#             .dice-header .message-icon-div {
#                 margin: 14px 6px 0 0;
#             }
#         }
#         .dice-header .navbar-toggler-override {
#             margin-top: 8px;
# background-image: url("data:image/svg+xml,%3csvg viewBox='0 0 30 30' xmlns='http://www.w3.org/2000/svg'%3e%3cpath stroke='white' stroke-width='3'             stroke-linecap='round' stroke-miterlimit='10' d='M4 7h26M4 15h26M4 23h26'/%3e%3c/svg%3e")!important;
#             }
#             }
#
# /*]]>*/
#   </style>
#   <style>
#    /*<![CDATA[*/
#
#         #dismissableComponent-1873702-568708033 {
#             font-weight: normal;
#             background: #006699;
#             color: #ffffff;
#             padding: 0 15px 0 15px;
#             min-height:
#         }
#         #dismissableComponent-1873702-568708033 .banner-close {
#             position: absolute;
#             top: 0;
#             right: 10px;
#             border: none;
#             padding: 10px 0 10px 0;
#             background: #006699;
#             color: #ffffff;
#             cursor: pointer;
#         }
#         #dismissableComponent-1873702-568708033 .banner-close-text {
#              font-size: 16px;
#              text-decoration: none;
#              margin-bottom: 5px;
#         }
#         #dismissableComponent-1873702-568708033 .dismiss-icon-spacing {
#              font-size: 16px;
#              padding-left: 5px;
#              padding-bottom: 5px;
#         }
#         #dismissableComponent-1873702-568708033 .row-space {
#              height: 1.5rem;
#         }
#         #dismissableComponent-1873702-568708033 .banner-headline {
#              font-family: Helvetica, Arial, sans-serif;
#              margin: 0;
#              font-size: 24px;
#              line-height: 1;
#         }
#         #dismissableComponent-1873702-568708033 .banner-text {
#              padding-right: 1em;
#              font-size: 18px;
#         }
#         #dismissableComponent-1873702-568708033 .banner-btn {
#              font-weight: normal;
#              text-decoration: none;
#              border-radius: 5px;
#         }
#         #dismissableComponent-1873702-568708033 .btn-inverse {
#              border: solid 1px #ffffff;
#              background-color: #006699;
#              color: #ffffff;
#         }
#         #dismissableComponent-1873702-568708033 .btn-inverse:hover {
#              border: solid 1px #006699;
#              background-color: #ffffff;
#              color: #006699;
#         }
#         #dismissableComponent-1873702-568708033 .btn-text {
#             font-size: 18px;
#         }
#         #dismissableComponent-1873702-568708033 .banner-button-connecting-text {
#              margin-top: 10px;
#              padding: 0 10px;
#              font-size: 18px;
#         }
#         #dismissableComponent-1873702-568708033 .icon-padding1 {
#            margin-left: 5px;
#         }
#
#         #dismissableComponent-1873702-568708033 .icon-padding2 {
#           margin-left: 5px;
#         }
#         #dismissableComponent-1873702-568708033 .icon-size {
#              font-size: 20px;
#         }
#         @media (min-width: 992px) {
#             #dismissableComponent-1873702-568708033 .banner-headline {
#                 font-size: 28px;
#             }
#         }
#
# /*]]>*/
#   </style>
#   <style>
#    /*<![CDATA[*/
#
#         .news .news-header {
#             margin-bottom: 25px;
#         }
#
#         /* For leadgen pages, use leadgen theme kit for dot creation*/
#             .news-video-1142693439 .dots {
#                 margin-right: 5px;
#             }
#             .news-video-1142693439 .dots .row-dot-1 {
#                 margin-bottom: 14px;
#             }
#             .news-video-1142693439 .dots .dot {
#                 margin-left: 14px;
#                 width: 6px;
#                 height: 6px;
#                 opacity: 0.25;
#                 background-color: #069;
#                 border-radius: 50%;
#             }
#
#         dhi-carousel {
#             margin-left: -15px;
#             margin-right: -15px;
#         }
#         .news-carousel .card {
#             overflow: hidden;
#         }
#         .news-carousel .card-text {
#             max-width: 100%;
#             font-weight: 300;
#             overflow: hidden;
#             text-overflow: ellipsis;
#             white-space: nowrap;
#         }
#         .carousel-news-card {
#             max-width: 344px;
#             border: none;
#         }
#         .carousel-news-card .news-image {
#             max-width: 360px;
#             height: 220px;
#             overflow: hidden;
#         }
#         .carousel-news-card .news-title {
#             font-size: 18px;
#             font-weight: normal;
#             font-stretch: normal;
#             font-style: normal;
#             line-height: 1.33;
#             letter-spacing: normal;
#             margin-bottom: 10px;
#             min-height: 4em;
#             hyphens: auto;
#         }
#         @media screen and (min-width: 992px) {
#             .carousel-news-card .news-title {
#                 min-height: 2.7em;
#             }
#         }
#
# /*]]>*/
#   </style>
#   <style type="text/css">
#    /*<![CDATA[*/
#
#         .seo-location {
#             width: 100%;
#         }
#         .seo-list-item {
#             display: list-item;
#             list-style-type: none;
#         }
#         .unauth-job-list {
#             margin-top: 1.8em;
#             -webkit-column-count: 4;
#             -moz-column-count: 4;
#             column-count: 4;
#             -webkit-column-width: 250px;
#             -moz-column-width: 250px;
#             column-width: 250px;
#             -webkit-column-gap: 2em;
#             -moz-column-gap: 2em;
#             column-gap: 2em;
#         }
#         .seo-location .homepage-h2-heading {
#             margin-bottom: 12px;
#         }
#         .seo-location a {
#             font-size: 18px;
#             color: #4a4a4a;
#         }
#         .seo-location .nav {
#             border-bottom: 1px solid #069;
#         }
#         .seo-location .tab-content li {
#             list-style-type: none;
#         }
#         .seo-location .nav a.active, .seo-location .nav a:hover {
#             border-bottom: 3px solid #069;
#             border-top: 0;
#             border-left: 0;
#             border-right: 0;
#             background-color: transparent;
#         }
#
# /*]]>*/
#   </style>
#   <style>
#    /*<![CDATA[*/
#
#         .animation-container {
#             padding-left: 24px;
#             padding-right: 36px;
#         }
#         .animation-container row {
#              /*  TODO  center align vertically the two col children inside this row.  */
#         }
#         .animation-text {
#             font-size: 20px;
#             line-height: 1.17;
#             font-weight: normal;
#         }
#         .animation-text h2 {
#             font-size: 36px;
#             font-weight: normal;
#             white-space: pre;
#         }
#         .animation-text h2, .animation-text .body-animation>* {
#             opacity: 0;
#         }
#         .active .animation-text h2, .active .animation-text .body-animation>* {
#             animation: 500ms ease-out slideUp;
#             animation-fill-mode: both;
#         }
#         .active .animation-text .body-animation>* {
#             animation-delay: .3s;
#         }
#         @media (min-width: 576px) {
#             .animation-text h2 {
#                 font-size: 40px;
#             }
#         }
#         @media (min-width: 991px) {
#             .animation-text {
#                 font-size: 24px;
#             }
#             .animation-text h2 {
#                 font-size: 50px;
#             }
#             .animation-container {
#                 padding-left: 43px;
#                 padding-right: 43px;
#             }
#         }
#         @keyframes slideUp {
#             0% {
#                 transform: translateY(100%);
#                 opacity: 0;
#             }
#             50% {
#                 transform: translateY(20%);
#                 opacity: .4;
#             }
#             100% {
#                 transform: translateY(0%);
#                 opacity: 1;
#             }
#         }
#
# /*]]>*/
#   </style>
#   <style type="text/css">
#    /*<![CDATA[*/
#
#         .text-center-dhi, .text-center-dhi .title, .text-center-dhi * {
#             width: 100%;
#             margin: 0 auto 0 auto;
#             font-weight: normal;
#             font-style: normal;
#             font-stretch: normal;
#             letter-spacing: normal;
#             text-align: center;
#             font-size: 21px;
#             line-height: 1.2;
#         }
#         .text-center-dhi .title {
#             font-size: 24px;
#             display: block;
#             margin-bottom: 13px;
#         }
#         @media screen and (max-width: 991px) {
#             .text-center-dhi {
#                 width: 90%;
#             }
#             .text-center-dhi .document-text>* {
#                 display: inline;
#             }
#         }
#
# /*]]>*/
#   </style>
#   <style>
#    /*<![CDATA[*/
#
#         .promo-dynamic-1397263635 {
#             margin-bottom: 2rem;
#             background-color: #cd2026;
#             color: #fff !important;
#         }
#         .promo-dynamic-1397263635 .row {
#             padding-top:  30px;
#             padding-bottom: 20px;
#             padding-left: 30px;
#             padding-right: 30px;
#             min-height: 90px;
#         }
#         .promo-dynamic-1397263635 .row.vertical-bar {
#             border-left: 2px solid #000000;
#
#         }
#         .promo-dynamic-1397263635 .headline-text {
#             font-size: 24px;
#             line-height: 28px;
#         }
#         .promo-dynamic-1397263635 .headline-text a {
#             color: #fff !important;
#         }
#         .promo-dynamic-1397263635 .main-content-text {
#             font-size: 20px;
#             line-height: 24px;
#         }
#         .promo-dynamic-1397263635 .main-content-text p {
#             margin-bottom: 0;
#         }
#         .promo-dynamic-1397263635 .promo-cta .btn {
#             font-size: 18px;
#             font-weight: 400;
#             max-width: 280px;
#             color: #ffffff;
#             background-color: #cd2026;
#         }
#         .promo-dynamic-1397263635 .promo-img img{
#             height: 90px;
#             max-width: 110px;
#             float: right;
#         }
#
#         @media (min-width: 400px) {
#             .promo-dynamic-1397263635 .promo-cta .btn {
#                 white-space: nowrap;
#             }
#         }
#
#         @media (min-width: 768px) {
#             .promo-dynamic-1397263635 .promo-cta .btn {
#                 min-width: 280px;
#             }
#         }
#
#         @media (min-width: 992px) {
#             .promo-dynamic-1397263635.promo-sticky {
#                 position: -webkit-sticky;
#                 position: sticky;
#                 top: 0;
#                 z-index: 2200;
#             }
#         }
#
# /*]]>*/
#   </style>
#   <style type="text/css">
#    /*<![CDATA[*/
#
#         #ctaArrowDecoration-fb8b2adc-5944-4f72-b05b-1c2531625e4b {
#             position: relative;
#             width: 60px;
#             height: 60px;
#             margin: 0 auto 0 auto;
#             border-radius: 50%;
#             font-size: 48px;
#             -webkit-text-stroke: 3px white;
#             color: #cb2026;
#             background-color: #ffffff;
#             text-align: center;
#             border: 1px solid rgba(142, 142, 142, 0.3);
#             box-shadow: 0 3px rgba(142, 142, 142, 0.5);
#             z-index: 2100;
#             line-height: 1.3em;
#             top: -40px;
#         }
#
#         #ctaArrowDecoration-fb8b2adc-5944-4f72-b05b-1c2531625e4b.cursor-pointer {
#             cursor: pointer;
#         }
#
#         #ctaArrowWrapper-fb8b2adc-5944-4f72-b05b-1c2531625e4b {
#             height: 0;
#             width: 100%;
#         }
#
#
#         /*@media screen and (max-width: 991px) {*/
#         /*    .arrow-decoration-box {*/
#         /*        width: 90%;*/
#         /*    }*/
#         /*}*/
#
# /*]]>*/
#   </style>
#   <style type="text/css">
#    /*<![CDATA[*/
#
#         .job-search-hero {
# background-image: url(/binaries/small/content/gallery/dice/home-page/hero-images/hero-04-mobile.jpg);            background-repeat: no-repeat;
#             background-position: right;
#             background-size: cover;
#             min-height: 41.5rem;
#         }
#         .job-search-hero .container {
#             padding-top: 4rem;
#         }
#         .job-search-hero .slot-words-container {
#             border-bottom: solid 2px black;
#             font-size: 1.8rem;
#             padding-bottom: 10px;
#         }
#         .job-search-word-carousel {
#             font-family: Helvetica, Arial, sans-serif;
#         }
#         .job-search-tagline {
#             font-size: 1rem;
#             font-weight: 600;
#         }
#         .job-search-hero .h1 {
#             margin-top: 1rem;
#         }
#         .dice-brand {
#             width: 129px;
#             padding-bottom: 1rem;
#         }
#         .hero-job-search-animation {
#             display: inline-block;
#             height: 1.43em;
#             overflow: hidden;
#             white-space: nowrap;
#             margin-bottom: -13px;
#         }
#         .hero-job-search-animation-window {
#             position: relative;
#             height: 100%;
#             transition: top 300ms linear, width 300ms linear;
#             margin: 0;
#             list-style: none;
#             padding-left: 0;
#         }
#
#         @media (min-width: 400px) {
#             .job-search-hero {
# background-image: url(/binaries/medium/content/gallery/dice/home-page/hero-images/hero-01-desktop.jpg);                background-repeat: no-repeat;
#                 background-position: right;
#                 background-size: cover;
#                 min-height: 41.5rem;
#             }
#             .job-search-hero .container {
#                 padding-top: 4rem;
#             }
#             .job-search-hero .slot-words-container {
#                 font-size: 2.3rem;
#             }
#             .hero-job-search-animation {
#                 margin-bottom: -18px;
#             }
#         }
#
#         @media (min-width: 992px) {
#             .job-search-hero {
#                 background-position: top;
# background-image: url(/binaries/large/content/gallery/dice/home-page/hero-images/hero-01-desktop.jpg);            }
#             .job-search-hero .container {
#                 padding-top: 5.7rem;
#             }
#             .job-search-hero .slot-words-container {
#                 font-size: 3.5rem;
#             }
#             .job-search-tagline {
#                 font-size: 1.6rem;
#             }
#             .dice-brand {
#                 width: 147px;
#             }
#             .hero-job-search-animation {
#                 height: 1.25em;
#             }
#             .hero-job-search-animation {
#                 margin-bottom: -18px;
#             }
#         }
#         @media (min-width: 1200px) {
#             .job-search-hero {
# background-image: url(/binaries/extralarge/content/gallery/dice/home-page/hero-images/hero-01-desktop.jpg);            }        }
#
# /*]]>*/
#   </style>
#   <link href="/binaries/content/assets/dice/homepage/job-search-v3.css" rel="stylesheet" type="text/css"/>
#   <script type="application/ld+json">
#    //<![CDATA[
# {
#   "@context": "http://schema.org",
#   "@type": "Organization",
#   "@id": "https://www.dice.com",
#   "name": "Dice.com",
#   "description": "Job search and career services website for jobseekers, recruiters and employers.",
#   "logo": "https://www.dice.com/binaries/content/gallery/dice/icons/dice-logo.svg",
#   "url": "https://www.dice.com",
#   "telephone": "1-800-979-3423",
#   "sameAs": [
#     "https://twitter.com/Dicedotcom",
#     "https://www.facebook.com/dice",
#     "https://en.wikipedia.org/wiki/Dice.com",
#     "https://www.crunchbase.com/organization/dice-com"
#   ],
#   "address": {
#     "@type": "PostalAddress",
#     "streetAddress": "6465 Greenwood Plaza Blvd",
#     "addressLocality": "Centennial",
#     "addressRegion": "Colorado",
#     "postalCode": "80111",
#     "addressCountry": "United States"
#   },
#   "parentOrganization": "DHI Group, Inc."
# }
# //]]>
#   </script>
#   <title>
#    Find Jobs in Technology
#   </title>
#   <meta content="Search 70,000+ job openings from tech's hottest employers. Salary estimations, career path tips and Insights to make your next career move the right one." name="description"/>
#   <link href="https://www.dice.com/" rel="canonical"/>
#   <!-- include optimize/funnel envy snippets based on component at bottom of head -->
#   <style>
#    /*<![CDATA[*/
# .async-hide { opacity:0!important}
# /*]]>*/
#   </style>
#   <script type="text/javascript">
#    //<![CDATA[
#
#         (function(a,s,y,n,c,h,i,d,e){s.className+=' '+y;h.start=1*new Date;
#             h.end=i=function(){s.className=s.className.replace(RegExp(' ?'+y),'')};
#             (a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;
#         })(window,document.documentElement,'async-hide','dataLayer',4000,
#                 {'GTM-WLPMJGK':true});
#
# //]]>
#   </script>
#   <!-- end of include optimize snippet based on component -->
#   <link href="https://job-search-dice-search-bar.dhishrdsvcprod.dhiaws.com/styles.0e6884d46d0e68ab3a34.css?v=1646842828433" rel="stylesheet" type="text/css"/>
#   <style>
#    .dhi-carousel-content{display:flex;width:100%;transition:transform 300ms ease}.dhi-carousel-content-wrapper{overflow:hidden;width:100%}.dhi-carousel-item{flex:1 1;width:32%;min-width:32%;max-width:32%;margin-left:1%;overflow:hidden;transition:width 300ms ease, min-width 300ms ease, max-width 300ms ease, margin-left 300ms ease 300ms, margin-right 300ms ease 300ms}.dhi-carousel-nav-item{border-radius:9px;height:18px;width:18px;border:solid black 1px;margin:4px;margin-top:15px;background-color:inherit;transition:background-color ease 600ms}.dhi-carousel-nav{display:flex;justify-content:center}.dhi-carousel-nav .active{background-color:#069;background-color:var(--color-primary, #069)}.dhi-carousel-arrow{background-color:white;cursor:pointer;height:100%;min-height:100%;border:0;font-size:1.5em;font-weight:900;color:var(--color-primary, #069);transform:scale(1, 1.6);-webkit-text-stroke-width:2.6px;-webkit-text-stroke-color:#069}.dhi-carousel-arrow-right{margin-right:10px;padding:20px}.dhi-carousel-arrow-left{margin-left:10px;padding:20px}.mobile-only,.hide{display:none}@media only screen and (min-width: 992px){.dhi-carousel-item:nth-child(3n){margin-right:1%}}@media only screen and (min-width: 768px) and (max-width: 991px){.md-show{display:block}.dhi-carousel-arrow{display:none}.dhi-carousel-item{width:46%;min-width:46%;max-width:46%;margin-left:2%;margin-right:2%}.dhi-carousel-item:nth-child(3n){margin-right:2%}.dhi-carousel-item.active{width:40%;min-width:40%;max-width:40%}.dhi-carousel-item.active:nth-child(1){width:43%;min-width:43%;max-width:43%}.dhi-carousel-item.active:nth-child(1)+.dhi-carousel-item{width:43%;min-width:43%;max-width:43%}.dhi-carousel-item.active+.dhi-carousel-item{width:40%;min-width:40%;max-width:40%}.dhi-carousel-item.left-of-active{margin-left:9%}}@media only screen and (max-width: 767px){.mobile-only{display:block}.dhi-carousel-arrow{display:none}.dhi-carousel-item{width:96%;min-width:96%;max-width:96%;margin-left:2%;margin-right:2%}.dhi-carousel-item.active{width:80%;min-width:80%;max-width:80%}.dhi-carousel-item.active:nth-child(1){width:88%;min-width:88%;max-width:88%}.dhi-carousel-item.left-of-active{margin-left:10%}}
#   </style>
#   <script async="" src="https://cdn.funnelenvy.com/client/production/bundle-5da5f32705fd1d7c0ba5a6ac.js" type="text/javascript">
#   </script>
#   <script async="" src="//munchkin.marketo.net/munchkin.js" type="text/javascript">
#   </script>
#   <script async="" src="https://maps.googleapis.com/maps/api/js?v=3.37&amp;libraries=places&amp;key=AIzaSyBV0FHgB6AEI9ASyCppVH0TpheK2mUZZyc&amp;language=en">
#   </script>
#   <script src="https://bm-test-dev.s3.us-east-2.amazonaws.com/funnelenvy/Dice/Dice-62-1/Dice-62-1JS.js" type="module">
#   </script>
#   <style>
#    dhi-opt-out-banner[_ngcontent-dvn-c27]   span[_ngcontent-dvn-c27]:nth-of-type(1){padding:10px 15px}dhi-opt-out-banner[_ngcontent-dvn-c27]   span[_ngcontent-dvn-c27]:nth-of-type(2){padding:10px 82px 10px 15px;display:flex;justify-content:flex-end}.count-header[_ngcontent-dvn-c27]{background-color:#fff;margin-bottom:0}
#   </style>
#   <style>
#    #searchInput-div.search-input[_ngcontent-dvn-c26]{background-color:#f0f6fc;box-shadow:0 2px #68a8de}@media (min-width: 0) and (max-width: 991px){#searchInput-div.search-input[_ngcontent-dvn-c26]{box-shadow:0 2px #007991}}#searchInput-div.search-input-widget[_ngcontent-dvn-c26]{background-color:#fff;padding-top:20px;box-shadow:0 2px 3px #5b5b5b40;margin-top:0;margin-bottom:1rem;border-radius:0}#searchInput-div[_ngcontent-dvn-c26]   input[_ngcontent-dvn-c26]{border-radius:0}#searchInput-div[_ngcontent-dvn-c26]   .inputs-row[_ngcontent-dvn-c26]{justify-content:center}#searchInput-div[_ngcontent-dvn-c26]   .inputs-row[_ngcontent-dvn-c26]   .input-examples[_ngcontent-dvn-c26]{padding:5px 0 15px}#searchInput-div[_ngcontent-dvn-c26]   .inputs-row[_ngcontent-dvn-c26]   .no-padding[_ngcontent-dvn-c26]{padding:0}#searchInput-div[_ngcontent-dvn-c26]   #submitSearch-button.btn[_ngcontent-dvn-c26]{margin-bottom:10px}#searchInput-div[_ngcontent-dvn-c26]   form[_ngcontent-dvn-c26]{padding:0 15px;display:block;border:none;box-shadow:none;border-radius:0}
#   </style>
#   <style>
#    .typeahead-content-area{width:100%;border:1px solid black;border-top:none;background-color:#fff}.cdk-overlay-backdrop.cdk-overlay-dark-backdrop.backdrop-transparent,.cdk-overlay-backdrop.cdk-overlay-dark-backdrop.cdk-overlay-backdrop-showing.backdrop-transparent{background-color:#0000}
#   </style>
#   <style>
#    .typeahead-menu-container .dropdown-item{width:100%;overflow:hidden;text-overflow:ellipsis}.typeahead-menu-container .dropdown-item.text-cap-first-letter:first-letter{text-transform:capitalize}
#   </style>
#   <style>
#    #google-location-search.is-invalid[_ngcontent-dvn-c23]{border-left:2px solid #c00;border-left:2px solid var(--red, #c00)}
#   </style>
#   <style>
#    .float-label-container{position:relative}.float-label-container .float-label-content{display:block;position:relative;flex:auto;min-width:0}.float-label-container .float-label-content .form-control{padding-bottom:.1rem}.float-label-wrapper{position:absolute;left:0;pointer-events:none;box-sizing:content-box;width:100%;height:100%;overflow:hidden;z-index:4}.dhi-floating-label{position:absolute;left:0;top:1px;pointer-events:none;font:inherit;white-space:nowrap;text-overflow:ellipsis;overflow:hidden;background-color:#fff;color:#757575;color:var(--gray600, #757575);font-style:italic;font-weight:300}.hide-placeholder .dhi-input-element::placeholder{color:transparent!important;-webkit-text-fill-color:transparent;transition:none}.hide-placeholder .dhi-input-element::-moz-placeholder{color:transparent!important;-webkit-text-fill-color:transparent;-moz-transition:none;transition:none}.hide-placeholder .dhi-input-element::-webkit-input-placeholder{color:transparent!important;-webkit-text-fill-color:transparent;-webkit-transition:none;transition:none}.hide-placeholder .dhi-input-element:-ms-input-placeholder{color:transparent!important;-webkit-text-fill-color:transparent;-ms-transition:none;transition:none}
#   </style>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <style type="text/css">
#    .fehide { opacity: 0 !important; }
#   </style>
#   <meta content="" http-equiv="origin-trial"/>
#   <script async="" src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/761321626/?random=1671315032481&amp;cv=11&amp;fst=1671315032481&amp;bg=ffffff&amp;guid=ON&amp;async=1&amp;gtm=2wgbu0&amp;u_w=1920&amp;u_h=1080&amp;hn=www.googleadservices.com&amp;frm=0&amp;url=https%3A%2F%2Fwww.dice.com%2F&amp;tiba=Find%20Jobs%20in%20Technology&amp;us_privacy=1YNN&amp;auid=2133759198.1671315032&amp;uaa=x86&amp;uab=64&amp;uafvl=Not%253FA_Brand%3B8.0.0.0%7CChromium%3B108.0.5359.124%7CGoogle%2520Chrome%3B108.0.5359.124&amp;uap=macOS&amp;uapv=13.0.1&amp;uaw=0&amp;rfmt=3&amp;fmt=4" type="text/javascript">
#   </script>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <script async="" data-ueto="ueto_41efbf778c" src="https://bat.bing.com/p/action/17093194.js" type="text/javascript">
#   </script>
#   <style media="print" nonce="4e6dc369a33b" type="text/css">
#    .usabilla_live_button_container { display: none; }
#   </style>
#   <style nonce="4e6dc369a33b" type="text/css">
#    iframe.usabilla-live-button#usabilla_live_button_container_iframe982817587{width:40px;height:130px;margin: 0;padding: 0;border: 0;overflow: hidden;z-index: 9998;position: absolute;left: 0;top: 0;box-shadow: 0 0 0;background-color: transparent;}
#   </style>
#   <script charset="UTF-8" src="https://maps.googleapis.com/maps-api-v3/api/js/50/12a/common.js" type="text/javascript">
#   </script>
#   <script charset="UTF-8" src="https://maps.googleapis.com/maps-api-v3/api/js/50/12a/util.js" type="text/javascript">
#   </script>
#  </head>
#  <body>
#   <div class="cmpwrapper" id="cmpwrapper">
#   </div>
#   <div id="lightningjs-usabilla_live" style="display: none;">
#    <div>
#     <iframe frameborder="0" id="lightningjs-frame-usabilla_live">
#     </iframe>
#    </div>
#   </div>
#   <script>
#    window.fraudElement = window.fraudElement || {};
#         window.fraudElement.beaconKey = "446c19b1eb";
#         window.fraudElement.peopleId = "";
#         window.fraudElement.sessionId = "";
#         window.fraudElement.emulatedSeeker = "false";
#   </script>
#   <script src="/webfiles/1670950067040/js/dice/vendor-fraud-tracking.js" type="text/javascript">
#   </script>
#   <!--  Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-WLPMJGK" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <script>
#    window.ssdl = window.ssdl || {};
#         window.ssdl.trackEvent = window.ssdl.trackEvent || function() {};
#   </script>
#   <div class="layout-main-content-wrapper">
#    <div class="" id="dismissableComponentAboveNavigation">
#     <div class="d-none d-md-block" data-an-category="Dismissible Marketing Content - Need Tech Talent?">
#      <div class="container-fluid" id="dismissableComponent-1873702-568708033">
#       <div class="row row-space mb-3 mb-md-0">
#        <div class="col-12">
#         <button class="banner-close dismisable-marketing-component-dismiss" data-analytics-component-id="dismissableComponent-1873702-568708033" data-analytics-event="dismissableComponent">
#          <span class="banner-close-text">
#           Don't show this message again
#          </span>
#          <span class="dice-icon icon-delete-1 dismiss-icon-spacing">
#          </span>
#         </button>
#        </div>
#       </div>
#       <div class="row mb-3 mb-md-0">
#        <div class="col-12">
#         <div aria-level="2" class="banner-headline" role="heading">
#          Need Technology Professionals?
#         </div>
#        </div>
#       </div>
#       <div class="row align-items-end pb-3">
#        <div class="col-12">
#         <div class="d-block d-md-inline-block banner-text">
#          <p>
#           Cut your time-to-hire with easy access to millions of relevant tech candidates
#          </p>
#         </div>
#         <div class="d-block d-md-inline-block">
#          <a class="btn banner-btn btn-inverse dismisable-marketing-component-click" data-analytics-component-id="dismissableComponent-1873702-568708033" data-analytics-event="dismissableComponent" href="https://techhub.dice.com/2019-homepagebannertest.html?fe-dice62=true">
#           <span class="dice-icon icon-magnifier icon-size">
#           </span>
#           <span class="icon-padding1 btn-text">
#            Search and Hire Technologists
#           </span>
#          </a>
#          <span class="banner-button-connecting-text">
#           or
#          </span>
#          <a class="btn banner-btn btn-inverse dismisable-marketing-component-click" data-analytics-component-id="dismissableComponent-1873702-568708033" data-analytics-event="dismissableComponent" href="https://www.dice.com/hiring/webstore">
#           <span class="dice-icon icon-document-1 icon-size">
#           </span>
#           <span class="icon-padding2 btn-text">
#            Post a Job
#           </span>
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div>
#     <div>
#      <header class="dice-header" data-an-category="candidateHeaderNavigation" data-analytics-event="headerNavigation">
#       <div class="has-edit-button">
#       </div>
#       <nav class="navbar navbar-expand-lg pt-1 pt-lg-0 pb-1 pb-lg-0">
#        <span class="diceLogoSuppressedSpacing">
#        </span>
#        <div id="sticky-header-nav-btn-mobile">
#         <a href="#" style="display:none">
#         </a>
#        </div>
#        <div class="d-block d-lg-none pr-2 pt-1 ml-auto">
#        </div>
#        <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbarSupportedContent" data-toggle="collapse" type="button">
#         <span class="navbar-toggler-icon navbar-toggler-override">
#         </span>
#        </button>
#        <div class="collapse navbar-collapse" id="navbarSupportedContent">
#         <ul class="navbar-nav mr-auto menu-left">
#          <li class="nav-item dropdown" data-analytics-parent="Tech Careers">
#           <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-item-analytics="" data-toggle="dropdown" href="#" id="navbarDropdown-2" role="button">
#            <span class="menu-icon dice-icon icon-clipboard">
#            </span>
#            Tech Careers
#            <div class="menu-toggle">
#             <span class="menu-active dice-icon icon-arrow-67">
#             </span>
#             <span class="menu-inactive dice-icon icon-arrow-68">
#             </span>
#            </div>
#           </a>
#           <div aria-labelledby="navbarDropdown-2" class="dropdown-menu">
#            <a class="dropdown-item" data-item-analytics="" href="/jobs">
#             Job Search
#            </a>
#            <a class="dropdown-item" data-item-analytics="" href="/career-events" target="_blank">
#             Career Events
#            </a>
#            <a class="dropdown-item" data-item-analytics="" href="/products/mobile-app">
#             Dice Careers Mobile
#            </a>
#           </div>
#          </li>
#          <li class="nav-item">
#           <a class="nav-item" data-item-analytics="" href="/career-advice">
#            <span class="menu-icon dice-icon icon-newspaper-2">
#            </span>
#            Career Advice
#           </a>
#          </li>
#          <li class="nav-item">
#           <a class="nav-item" data-item-analytics="" href="/career-development">
#            <span class="newItemIcon mr-2">
# ...
#                         clearInterval(interval);
#                         window.onresize = function(event) {
#                             animWindow.removeAttribute('style');
#                         };
#                     }
#                 }, 1200);
#             }
#
#             function createLis(listItems) {
#                 // listItems.reverse();
#                 for(let i = 0; i < listItems.length; i++) {
#                     if(i < words.length) {
#                         listItems.push(listItems[i].cloneNode(true));
#                     }
#                     animWindow.appendChild(listItems[i]);
#                 }
#                 startAnimation();
#             }
#
#             function setWordLength(i) {
#                 if(i >= words.length) {
#                     createLis(liEls);
#                     return;
#                 }
#                 const li = document.createElement('li');
#                 liEls.push(li);
#                 li.textContent = words[i];
#                 animWindow.appendChild(li);
#                 const interval = setInterval(function() {
#                     if(li.offsetWidth) {
#                         clearInterval(interval);
#                         wordLengths.push(li.offsetWidth + 'px');
#                         animWindow.removeChild(li);
#                         setWordLength(++i);
#                     }
#                 }, 1);
#             }
#             setWordLength(0);
#         })();
#
# //]]>
#   </script>
#   <!-- end of include -->
#   <div style="display: none; visibility: hidden;">
#    <script type="text/javascript">
#     window.lightningjs||function(c){function m(n,p){p&&(p+=(/\?/.test(p)?"\x26":"?")+"lv\x3d1");c[n]||function(){var v=window,h=document,q=n,A=h.location.protocol,x="load",E=0;(function(){function y(){a.P(x);a.w=1;c[q]("_load")}c[q]=function(){function e(){e.id=b;return c[q].apply(e,arguments)}var b=++E;var t=this&&this!=v?this.id||0:0;(a.s=a.s||[]).push([b,t,arguments]);e.then=function(r,k,l){var u=a.fh[b]=a.fh[b]||[],z=a.eh[b]=a.eh[b]||[],d=a.ph[b]=a.ph[b]||[];r&&u.push(r);k&&z.push(k);l&&d.push(l);
# return e};return e};var a=c[q]._={};a.fh={};a.eh={};a.ph={};a.l=p?p.replace(/^\/\//,("https:"==A?A:"http:")+"//"):p;a.p={0:+new Date};a.P=function(e){a.p[e]=new Date-a.p[0]};a.w&&y();v.addEventListener?v.addEventListener(x,y,!1):v.attachEvent("on"+x,y);var B=function(){function e(){return["\x3chead\x3e\x3c/head\x3e\x3c",b,' onload\x3d"var d\x3d',w,";d.getElementsByTagName('head')[0].",r,"(d.",k,"('script')).",l,"\x3d'",a.l,"'\"\x3e\x3c/",b,"\x3e"].join("")}var b="body",t=h[b];if(!t)return setTimeout(B,
# 100);a.P(1);var r="appendChild",k="createElement",l="src",u=h[k]("div"),z=u[r](h[k]("div")),d=h[k]("iframe"),w="document";u.style.display="none";t.insertBefore(u,t.firstChild).id=f+"-"+q;d.frameBorder="0";d.id=f+"-frame-"+q;/MSIE[ ]+6/.test(navigator.userAgent)&&(d[l]="javascript:false");d.allowTransparency="true";z[r](d);try{d.contentWindow[w].open()}catch(F){a.domain=h.domain;var C="javascript:var d\x3d"+w+".open();d.domain\x3d'"+h.domain+"';";d[l]=C+"void(0);"}try{var D=d.contentWindow[w];D.write(e());
# D.close()}catch(F){d[l]=C+'d.write("'+e().replace(/"/g,String.fromCharCode(92)+'"')+'");d.close();'}a.P(2)};a.l&&setTimeout(B,0)})()}();c[n].lv="1";return c[n]}var f="lightningjs",g=window[f]=m(f);g.require=m;g.modules=c}({});navigator.userAgent.match(/Android|BlackBerry|BB10|iPhone|iPad|iPod|Opera Mini|IEMobile/i)?window.usabilla_live=lightningjs.require("usabilla_live","//w.usabilla.com/f7ea136091dc.js"):window.usabilla_live=lightningjs.require("usabilla_live","//w.usabilla.com/4e6dc369a33b.js");
# window.usabilla_live("setEventCallback",function(c,m,f){if("Campaign:Open"===m){c="campaign_shown";m="true";f=604800;f*=1E3;var g=new Date,n=g.getTime();g.setTime(n+f);g=g.toUTCString();document.cookie=c+"\x3d"+m+"; SameSite\x3dNone; Secure; expires\x3d"+g+"; path\x3d/; domain\x3d."+location.hostname.replace(/^www\./i,"")}});
#    </script>
#   </div>
#   <div style="display: none; visibility: hidden;">
#    <script>
#     window.gdprAppliesGlobally=!0;if(!("cmp_id"in window)||1>window.cmp_id)window.cmp_id=0;"cmp_cdid"in window||(window.cmp_cdid="e7c754694a55");"cmp_params"in window||(window.cmp_params="");"cmp_host"in window||(window.cmp_host="c.delivery.consentmanager.net");"cmp_cdn"in window||(window.cmp_cdn="cdn.consentmanager.net");"cmp_proto"in window||(window.cmp_proto="https:");"cmp_codesrc"in window||(window.cmp_codesrc="1");
# window.cmp_getsupportedLangs=function(){var c="DE EN FR IT NO DA FI ES PT RO BG ET EL GA HR LV LT MT NL PL SV SK SL CS HU RU SR ZH TR UK AR BS".split(" ");if("cmp_customlanguages"in window)for(var a=0;a<window.cmp_customlanguages.length;a++)c.push(window.cmp_customlanguages[a].l.toUpperCase());return c};window.cmp_getRTLLangs=function(){return["AR"]};
# window.cmp_getlang=function(c){"boolean"!=typeof c&&(c=!0);if(c&&"string"==typeof cmp_getlang.usedlang&&""!==cmp_getlang.usedlang)return cmp_getlang.usedlang;c=window.cmp_getsupportedLangs();var a=[],d=location.hash,b=location.search,e="languages"in navigator?navigator.languages:[];if(-1!=d.indexOf("cmplang\x3d"))a.push(d.substr(d.indexOf("cmplang\x3d")+8,2).toUpperCase());else if(-1!=b.indexOf("cmplang\x3d"))a.push(b.substr(b.indexOf("cmplang\x3d")+8,2).toUpperCase());else if("cmp_setlang"in window&&
# ""!=window.cmp_setlang)a.push(window.cmp_setlang.toUpperCase());else if(0<e.length)for(d=0;d<e.length;d++)a.push(e[d]);"language"in navigator&&a.push(navigator.language);"userLanguage"in navigator&&a.push(navigator.userLanguage);e="";for(d=0;d<a.length;d++){b=a[d].toUpperCase();if(-1!=c.indexOf(b)){e=b;break}-1!=b.indexOf("-")&&(b=b.substr(0,2));if(-1!=c.indexOf(b)){e=b;break}}if(""==e&&"string"==typeof cmp_getlang.defaultlang&&""!==cmp_getlang.defaultlang)return cmp_getlang.defaultlang;""==e&&(e=
# "EN");return e=e.toUpperCase()};
# (function(){function c(g,p){g+="\x3d";var k=g.length;if(-1!=location.hash.indexOf(g))g=location.hash.substr(location.hash.indexOf(g)+k,9999);else if(-1!=location.search.indexOf(g))g=location.search.substr(location.search.indexOf(g)+k,9999);else return p;-1!=g.indexOf("\x26")&&(g=g.substr(0,g.indexOf("\x26")));return g}var a=document,d=window,b="",e="_en";if("cmp_getlang"in d){b=d.cmp_getlang().toLowerCase();if("cmp_customlanguages"in d)for(var f=0;f<d.cmp_customlanguages.length;f++)if(d.cmp_customlanguages[f].l.toUpperCase()==b.toUpperCase()){b=
# "en";break}e="_"+b}var l="cmp_proto"in d?d.cmp_proto:"https:",h=["cmp_id","cmp_params","cmp_host","cmp_cdn","cmp_proto"];for(f=0;f<h.length;f++)"%%%"!=c(h[f],"%%%")&&(window[h[f]]=c(h[f],""));h="cmp_ref"in d?d.cmp_ref:location.href;f=a.createElement("script");f.setAttribute("data-cmp-ab","1");var m=c("cmpdesign",""),n=c("cmpregulationkey","");f.src=l+"//"+d.cmp_host+"/delivery/cmp.php?"+("cmp_id"in d&&0<d.cmp_id?"id\x3d"+d.cmp_id:"")+("cmp_cdid"in d?"cdid\x3d"+d.cmp_cdid:"")+"\x26h\x3d"+encodeURIComponent(h)+
# (""!=m?"\x26cmpdesign\x3d"+encodeURIComponent(m):"")+(""!=n?"\x26cmpregulationkey\x3d"+encodeURIComponent(n):"")+("cmp_params"in d?"\x26"+d.cmp_params:"")+(0<a.cookie.length?"\x26__cmpfcc\x3d1":"")+"\x26l\x3d"+b.toLowerCase()+"\x26o\x3d"+(new Date).getTime();f.type="text/javascript";f.async=!0;a.currentScript?a.currentScript.parentElement.appendChild(f):a.body?a.body.appendChild(f):(b=a.getElementsByTagName("body"),0==b.length&&(b=a.getElementsByTagName("div")),0==b.length&&(b=a.getElementsByTagName("span")),
# 0==b.length&&(b=a.getElementsByTagName("ins")),0==b.length&&(b=a.getElementsByTagName("script")),0==b.length&&(b=a.getElementsByTagName("head")),0<b.length&&b[0].appendChild(f));f=a.createElement("script");f.src=l+"//"+d.cmp_cdn+"/delivery/js/cmp"+e+".min.js";f.type="text/javascript";f.setAttribute("data-cmp-ab","1");f.async=!0;a.currentScript?a.currentScript.parentElement.appendChild(f):a.body?a.body.appendChild(f):(b=a.getElementsByTagName("body"),0==b.length&&(b=a.getElementsByTagName("div")),
# 0==b.length&&(b=a.getElementsByTagName("span")),0==b.length&&(b=a.getElementsByTagName("ins")),0==b.length&&(b=a.getElementsByTagName("script")),0==b.length&&(b=a.getElementsByTagName("head")),0<b.length&&b[0].appendChild(f))})();window.cmp_addFrame=function(c){if(!window.frames[c])if(document.body){var a=document.createElement("iframe");a.style.cssText="display:none";a.name=c;document.body.appendChild(a)}else window.setTimeout(window.cmp_addFrame,10,c)};
# window.cmp_rc=function(c){for(var a=document.cookie,d="",b=0;""!=a&&100>b;){for(b++;" "==a.substr(0,1);)a=a.substr(1,a.length);var e=a.substring(0,a.indexOf("\x3d")),f=-1!=a.indexOf(";")?a.substring(a.indexOf("\x3d")+1,a.indexOf(";")):a.substr(a.indexOf("\x3d")+1,a.length);c==e&&(d=f);e=a.indexOf(";")+1;0==e&&(e=a.length);a=a.substring(e,a.length)}return d};
# window.cmp_stub=function(){var c=arguments;__cmp.a=__cmp.a||[];if(c.length)if("ping"===c[0])if(2===c[1])c[2]({gdprApplies:gdprAppliesGlobally,cmpLoaded:!1,cmpStatus:"stub",displayStatus:"hidden",apiVersion:"2.0",cmpId:31},!0);else c[2](!1,!0);else if("getUSPData"===c[0])c[2]({version:1,uspString:window.cmp_rc("")},!0);else if("getTCData"===c[0])__cmp.a.push([].slice.apply(c));else if("addEventListener"===c[0]||"removeEventListener"===c[0])__cmp.a.push([].slice.apply(c));else if(4==c.length&&!1===
# c[3])c[2]({},!1);else __cmp.a.push([].slice.apply(c));else return __cmp.a};
# window.cmp_msghandler=function(c){var a="string"===typeof c.data;try{var d=a?JSON.parse(c.data):c.data}catch(e){d=null}if("object"===typeof d&&null!==d&&"__cmpCall"in d){var b=d.__cmpCall;window.__cmp(b.command,b.parameter,function(e,f){e={__cmpReturn:{returnValue:e,success:f,callId:b.callId}};c.source.postMessage(a?JSON.stringify(e):e,"*")})}"object"===typeof d&&null!==d&&"__uspapiCall"in d&&(b=d.__uspapiCall,window.__uspapi(b.command,b.version,function(e,f){e={__uspapiReturn:{returnValue:e,success:f,
# callId:b.callId}};c.source.postMessage(a?JSON.stringify(e):e,"*")}));"object"===typeof d&&null!==d&&"__tcfapiCall"in d&&(b=d.__tcfapiCall,window.__tcfapi(b.command,b.version,function(e,f){e={__tcfapiReturn:{returnValue:e,success:f,callId:b.callId}};c.source.postMessage(a?JSON.stringify(e):e,"*")},b.parameter))};
# window.cmp_setStub=function(c){c in window&&("function"===typeof window[c]||"object"===typeof window[c]||"undefined"!==typeof window[c]&&null===window[c])||(window[c]=window.cmp_stub,window[c].msgHandler=window.cmp_msghandler,window.addEventListener("message",window.cmp_msghandler,!1))};window.cmp_addFrame("__cmpLocator");"cmp_disableusp"in window&&window.cmp_disableusp||window.cmp_addFrame("__uspapiLocator");"cmp_disabletcf"in window&&window.cmp_disabletcf||window.cmp_addFrame("__tcfapiLocator");
# window.cmp_setStub("__cmp");"cmp_disabletcf"in window&&window.cmp_disabletcf||window.cmp_setStub("__tcfapi");"cmp_disableusp"in window&&window.cmp_disableusp||window.cmp_setStub("__uspapi");
#    </script>
#    <script async="" data-cmp-ab="1" src="https://c.delivery.consentmanager.net/delivery/cmp.php?cdid=e7c754694a55&amp;h=https%3A%2F%2Fwww.dice.com%2F&amp;&amp;__cmpfcc=1&amp;l=en&amp;o=1671315031398" type="text/javascript">
#    </script>
#    <script async="" data-cmp-ab="1" src="https://cdn.consentmanager.net/delivery/js/cmp_en.min.js" type="text/javascript">
#    </script>
#   </div>
#   <iframe name="__cmpLocator" style="display: none;">
#   </iframe>
#   <iframe name="__uspapiLocator" style="display: none;">
#   </iframe>
#   <iframe name="__tcfapiLocator" style="display: none;">
#   </iframe>
#   <script async="" data-cmp-ab="1" src="https://cdn.consentmanager.net/delivery/customdata/bV8xLndfMzAzOTQuZF8xNDQ1MC54XzI1Ni52LnAudF8xNDQ1MA.js" type="text/javascript">
#   </script>
#   <div id="criteo-tags-div" style="display: none;">
#   </div>
#   <iframe height="0" src="//11164823.fls.doubleclick.net/activityi;src=11164823;type=invmedia;cat=b2csi0;ord=6069606279199;gtm=2wgbu0;gcs=G111;auiddc=2133759198.1671315032;~oref=https%3A%2F%2Fwww.dice.com%2F?" style="display: none; visibility: hidden;" width="0">
#   </iframe>
#   <iframe data-cmp-ab="1" name="__cmpcdframe" src="https://cdn.consentmanager.net/delivery/crossdomain.html" style="display: none;">
#   </iframe>
#   <script id="" type="text/javascript">
#    !function(a,b){if(!a.rdt){var c=a.rdt=function(){c.sendEvent?c.sendEvent.apply(c,arguments):c.callQueue.push(arguments)};c.callQueue=[];a=b.createElement("script");a.src="https://www.redditstatic.com/ads/pixel.js";a.async=!0;b=b.getElementsByTagName("script")[0];b.parentNode.insertBefore(a,b)}}(window,document);rdt("init","t2_9sg6ip9c");rdt("track","PageVisit");
#   </script>
#   <script id="" type="text/javascript">
#    !function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","412179360593168");fbq("track","PageView");
#   </script>
#   <noscript>
#    <img height="1" src="https://www.facebook.com/tr?id=412179360593168&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#   </noscript>
#   <script id="" type="text/javascript">
#    (function(){var a=String(Math.floor(1E16*Math.random()));(new Image).src="https://pubads.g.doubleclick.net/activity;xsp\x3d4911983;ord\x3d"+a+"?"})();
#   </script>
#   <noscript>
#    <img border="0" height="1" src="https://pubads.g.doubleclick.net/activity;xsp=4911983;ord=1?" width="1"/>
#   </noscript>
#   <script id="" type="text/javascript">
#    (function(c,d,f,g,e){c[e]=c[e]||[];var h=function(){var b={ti:"17093194"};b.q=c[e];c[e]=new UET(b);c[e].push("pageLoad")};var a=d.createElement(f);a.src=g;a.async=1;a.onload=a.onreadystatechange=function(){var b=this.readyState;b&&"loaded"!==b&&"complete"!==b||(h(),a.onload=a.onreadystatechange=null)};d=d.getElementsByTagName(f)[0];d.parentNode.insertBefore(a,d)})(window,document,"script","//bat.bing.com/bat.js","uetq");
#   </script>
#   <div id="batBeacon593523433487" style="width:0px; height:0px; display:none; visibility:hidden;">
#    <img alt="" height="0" id="batBeacon672941770386" src="https://bat.bing.com/action/0?ti=17093194&amp;Ver=2&amp;mid=1bb5ec2b-a55e-47e7-b879-0d9b27cd61b8&amp;sid=9fc3f7a07e5711edb50cc3d3f4ebc241&amp;vid=9fc40d107e5711ed92fb195b6faf1d81&amp;vids=1&amp;msclkid=N&amp;pi=918639831&amp;lg=en-US&amp;sw=1920&amp;sh=1080&amp;sc=24&amp;tl=Find%20Jobs%20in%20Technology&amp;p=https%3A%2F%2Fwww.dice.com%2F&amp;r=&amp;lt=1394&amp;evt=pageLoad&amp;sv=1&amp;rn=872064" style="width:0px; height:0px; display:none; visibility:hidden;" width="0"/>
#   </div>
#   <script src="https://cdn.sift.com/s.js">
#   </script>
#   <div aria-label="Usabilla Feedback Button" class="usabilla_live_button_container" id="usabilla_live_button_container_930491586" role="button" tabindex="0">
#    <style nonce="4e6dc369a33b" type="text/css">
#     div.usabilla_live_button_container#usabilla_live_button_container_930491586[role="button"] {z-index:999;right:0;top:50%;margin-top:-65px;width:40px;height:130px;position:fixed}
#    </style>
#    <iframe class="usabilla-live-button" data-tags="right" frameborder="0" id="usabilla_live_button_container_iframe982817587" marginheight="0" marginwidth="0" scrolling="no" src="" title="Usabilla Feedback Button">
#    </iframe>
#   </div>
#   <iframe height="0" style="display: none;" title="Criteo DIS iframe" width="0">
#   </iframe>
#   <script id="" type="text/javascript">
#    window.usabilla_live("data",{custom:{userProfileParty:google_tag_manager["GTM-WLPMJGK"].macro(50)||"unknown",CandidateID:google_tag_manager["GTM-WLPMJGK"].macro(51)||"unknown",EmployerID:google_tag_manager["GTM-WLPMJGK"].macro(52)||"unknown",loginStatus:window.ssdl&&window.ssdl.user?"Logged In":"Logged Out"}});
#   </script>
#   <script id="" type="text/javascript">
#    try{window&&window.intercomSettings&&(window.intercomSettings.funnelenvy_visitor_id=google_tag_manager["GTM-WLPMJGK"].macro(53)||"")}catch(a){};
#   </script>
#  </body>
# </html>

# %%
soup= BeautifulSoup(browser.html, 'lxml')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup.body.text
# Out:
# "\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDon't show this message again\n\n\n\n\n\n\nNeed Technology Professionals?\n\n\n\n\nCut your time-to-hire with easy access to millions of relevant tech candidates\n\n\n \nSearch and Hire Technologists\n\n\n                           or\n                        \n\n \nPost a Job\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xa0Tech Careers\n\xa0 \n\n\n\nJob Search    \n\nCareer Events    \n\nDice Careers Mobile    \n\n\n\n\n\xa0Career Advice    \n\n\n\n\n                NEW\n            \n                Career Development Resources\n    \n\n\n\n\nFor Employers\n\xa0 \n\n\n\nSearch Resumes    \n\nPost Jobs    \n\nTalent Solutions    \n\nRecruiting Advice    \n\nResource Library    \n\n2022 Salary Report    \n\n\n\n\nContact Sales    \n\n\nLogin/Register\n\xa0 \n\n\n\nLogin    \n\nRegister    \n\n\nEmployer Login    \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDevelopChangeEngineerDesignDevelopChangeEngineerDesignyour world\n\n\nSet your tech career in motion with Dice\n\n\n\nSearch Term Input Job title, Keywords Google Location Search City, Zipcode  Search Jobs \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nThe Dice Tech Job Report is now available. Get the latest insights into where technologists are living and working, what skills employers value most and other hiring trends that could shape your job search.\n\xa0\n \n\n\n\n                            Read the Report\n                        \n\n\n\n\n\n\n\n\n\n\n\nDice is the leading career destination for tech experts at every stage of their careers. \n\n\n\n\n\n\n\n\n\n\n\n\n\n\nFIND YOUR\nPERFECT\nJOB MATCH\n\nSearch results tuned precisely to the criteria you set so we can better connect you with relevant and personalized tech positions. \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nTAKE CONTROL\nOVER YOUR\nCONTENT\n\nActively searching? Just browsing? Set personalized job alerts and control your profile visibility to get noticed by top tech employers. \n\n\n\n\n\n\n\n\n\n\n\n\nGAIN INSIGHTS\nINTO YOUR\nTECH CAREER\n\nWith your free Dice profile and our advanced data insights, you have access to the jobs, companies and analysis to level up your tech career. \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n        Get Started For Free\n    \n\n\n\n\n\n\n\n\n\n\n                        BROWSE JOBS\n                    \n\n\nBy Title\n                                \nBy Skill\n                                \nBy Category\n                                \nPopular Searches\n                                \n\n\n\n\nProject Manager\nData Analyst\nDBA\nScrum Master\nWeb Developer\nProduct Manager\nFull Stack Developer\nAndroid Developer\nProgram Manager\nSQL Developer\nFrontend Developer\nNetwork Engineer\nSystems Administrator\nSolution Architect\nDevOps Engineer\nGame Developer\nNetwork Administrator\nSalesforce Developer\nBackend Developer\nMachine Learning Engineer\n.Net Developer\nPHP Developer\nPython Developer\nMobile Developer\nLinux Administrator\n\n\nC\nCryptocurrency\nBlockchain\nDocker\nJavaScript\nSQL\nArtificial intelligence\nBig data\nChef\nMATLAB\nDjango\nMongoDB\nTensorFlow\nAgile\nMachine learning\nKanban\nC#\nGraphQL\nData mining\nNeural networks\nScala\nDeep learning\nGroovy\nApache Kafka\nSAP HANA\nErlang\nObjective-C\n\n\nPart time jobs\nAzure\nSelenium\nServiceNow\nSplunk\nWork from home\nRemote jobs\nETL\nMulesoft\nBusiness Analyst\nXamarin\nCognos\nTelecommute jobs\nPega\nStartup jobs\nSDET\nDoD jobs\nSAP ABAP\n\n\n.NET\nJava\nPython\nOracle\nSpring\nTableau\nCloud\nLinux\nRuby\nAngularJS\nSpark\nC++\nCyber security\nMySQL\nData Scientist\nSwift\nAmazon Web Services\nDevOps\nHadoop\nQA\nElasticsearch\nKotlin\nReact.js\nBusiness Analyst\nDeveloper\nPerl\nUX\niOS Developer\n\n\n\n\n\n\n\n\n\n\n\n\nWHAT'S NEW IN TECH\n\n\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\n\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\xa0\n\n\n\n\n\n < \n\n\n\n\n\n\n\n\nProject Manager Career Path: What's Best for You?\n\n\n            Nick Kolakowski,\nDec 16, 2022   ...

# %%
listjobs = soup.find_all('div', {"class":"ng-star-inserted"})
len(listjobs)
# Out:
# 2

# %%
listjob = listjobs[1]
listjob
# Out:
# <div _ngcontent-dvn-c23="" class="input-group-prepend ng-tns-c23-1 ng-star-inserted"><button _ngcontent-dvn-c23="" aria-label="Use current location" class="btn btn-outline-primary btn-input btn-geolocation ng-tns-c23-1" data-cy="reverse-geocode-button" id="IPGeoLocateButton" name="reverse-geocode" role="button" style="width: inherit; height: inherit;" type="button"><span _ngcontent-dvn-c23="" class="fa fa-lg fa-map-marker ng-tns-c23-1 fa-fw"></span></button></div>

# %%
glassdoor_data = "./glassdoor_jobs.csv"

# %%
df1 = pd.read_csv(glassdoor_data)
df1.head()
# Out:
#    Unnamed: 0                  Job Title              Salary Estimate  \
# 0           0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1           1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2           2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3           3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4           4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# 2                                KnowBe4\n4.8   Clearwater, FL
# 3                                   PNNL\n3.8     Richland, WA
# 4                     Affinity Solutions\n2.9     New York, NY
#
#      Headquarters                    Size  Founded   Type of ownership  \
# 0      Goleta, CA   501 to 1000 employees     1973   Company - Private
# 1   Baltimore, MD        10000+ employees     1984  Other Organization
# 2  Clearwater, FL   501 to 1000 employees     2010   Company - Private
# 3    Richland, WA  1001 to 5000 employees     1965          Government
# 4    New York, NY     51 to 200 employees     1998   Company - Private
#
#                            Industry                        Sector  \
# 0               Aerospace & Defense           Aerospace & Defense
# 1  Health Care Services & Hospitals                   Health Care
# 2                 Security Services             Business Services
# 3                            Energy  Oil, Gas, Energy & Utilities
# 4           Advertising & Marketing             Business Services
#
#                             Revenue  \
# 0         $50 to $100 million (USD)
# 1            $2 to $5 billion (USD)
# 2        $100 to $500 million (USD)
# 3  $500 million to $1 billion (USD)
# 4          Unknown / Non-Applicable
#
#                                          Competitors
# 0                                                 -1
# 1                                                 -1
# 2                                                 -1
# 3  Oak Ridge National Laboratory, National Renewa...
# 4               Commerce Signals, Cardlytics, Yodlee
