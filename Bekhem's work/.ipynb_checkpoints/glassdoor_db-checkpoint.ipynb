# %%
import pandas as pd
import numpy as np

# %%
file = "glassdoor_jobs.csv"
df=pd.read_csv(file)
df
# Out:
#      Unnamed: 0                                          Job Title  \
# 0             0                                     Data Scientist
# 1             1                          Healthcare Data Scientist
# 2             2                                     Data Scientist
# 3             3                                     Data Scientist
# 4             4                                     Data Scientist
# ..          ...                                                ...
# 951         951                               Senior Data Engineer
# 952         952  Project Scientist - Auton Lab, Robotics Institute
# 953         953                               Data Science Manager
# 954         954                                      Data Engineer
# 955         955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# ...

# %%
#We have annual and hourly within the "Salary Estimated" column.
df.sort_values(["Salary Estimate"], ascending=True)
# Out:
#      Unnamed: 0                                          Job Title  \
# 787         787  Senior Operations Data Analyst, Call Center Op...
# 523         523  Senior Operations Data Analyst, Call Center Op...
# 90           90                                     Data Scientist
# 224         224           Senior Data & Machine Learning Scientist
# 369         369           Senior Data & Machine Learning Scientist
# ..          ...                                                ...
# 208         208  Principal Data Scientist with over 10 years ex...
# 936         936                   ENVIRONMENTAL ENGINEER/SCIENTIST
# 464         464                   ENVIRONMENTAL ENGINEER/SCIENTIST
# 694         694                   ENVIRONMENTAL ENGINEER/SCIENTIST
# 377         377                               Data Operations Lead
#
#                                Salary Estimate  \
# 787           $10-$17 Per Hour(Glassdoor est.)
# 523           $10-$17 Per Hour(Glassdoor est.)
# ...

# %%
df1 = df.copy()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 956 entries, 0 to 955
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         956 non-null    int64
#  1   Job Title          956 non-null    object
#  2   Salary Estimate    956 non-null    object
#  3   Job Description    956 non-null    object
#  4   Rating             956 non-null    float64
#  5   Company Name       956 non-null    object
#  6   Location           956 non-null    object
#  7   Headquarters       956 non-null    object
#  8   Size               956 non-null    object
#  9   Founded            956 non-null    int64
#  10  Type of ownership  956 non-null    object
#  11  Industry           956 non-null    object
#  12  Sector             956 non-null    object
#  13  Revenue            956 non-null    object
#  14  Competitors        956 non-null    object
# dtypes: float64(1), int64(2), object(12)
# ...

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Job Title', 'Salary Estimate', 'Job Description',
#        'Rating', 'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors'],
#       dtype='object')

# %%
df1.groupby('Job Title').sum()
# Out:
#                                                     Unnamed: 0  Rating  \
# Job Title
# ATL - Data & Analytics (DA)                                261     4.3
# AWS Data Engineer                                          581     9.0
# Advanced Analytics Manager                                1201     9.6
# Ag Data Scientist                                          130     4.6
# Analytics - Business Assurance Data Analyst               1289     9.2
# ...                                                        ...     ...
# Technology-Minded, Data Professional Opportunities        1242     9.4
# UX Data Scientist (Python)                                1236    13.2
# VP, Data Science                                           569     6.4
# Weapons and Sensors Engineer/Scientist – Entry ...         151     3.8
# Web Data Analyst                                            36     4.2
#
#                                                     Founded
# Job Title
# ...

# %%
df1.groupby('Salary Estimate').sum()
# Out:
#                                            Unnamed: 0  Rating  Founded
# Salary Estimate
# $10-$17 Per Hour(Glassdoor est.)                 1310     5.4     4000
# $100K-$160K (Glassdoor est.)                       90     4.5     1942
# $100K-$166K (Glassdoor est.)                      593     6.0     4030
# $100K-$173K (Glassdoor est.)                     1344     7.8     4014
# $100K-$190K (Glassdoor est.)                      482     7.0     4020
# ...                                               ...     ...      ...
# Employer Provided Salary:$120K-$145K              980     4.0     2016
# Employer Provided Salary:$150K-$160K              525    10.0       -2
# Employer Provided Salary:$200K-$250K              539    -2.0     4034
# Employer Provided Salary:$25-$28 Per Hour        2094     9.9     5928
# Employer Provided Salary:$85K-$90K                377    -1.0       -1
#
# [417 rows x 3 columns]

# %%
df1.groupby('Location').sum()
# Out:
#                   Unnamed: 0  Rating  Founded
# Location
# Agoura Hills, CA         332     3.2     2008
# Alabaster, AL            143     4.0     2000
# Alameda, CA             1548     6.0     3988
# Albuquerque, NM          599    10.8     5713
# Alexandria, VA          2390    20.3     9927
# ...                      ...     ...      ...
# Winter Park, FL          521     8.4     4012
# Woburn, MA                38     4.7     2010
# Woodbridge, NJ           540     6.6     3964
# Woodinville, WA          340     3.6     1996
# Worcester, MA           2234    18.5     9260
#
# [237 rows x 3 columns]

# %%
df1.groupby('Industry').sum()
# Out:
#                                       Unnamed: 0  Rating  Founded
# Industry
# -1                                         22489     1.0      -39
# Accounting                                   575     4.0       -1
# Advertising & Marketing                     8943    89.0    49890
# Aerospace & Defense                        13304   128.3    61165
# Architectural & Engineering Services        1732    17.8     7873
# ...                                          ...     ...      ...
# Travel Agencies                             4600    30.3    16025
# Trucking                                     266     4.3     1981
# Utilities                                    360    -1.0       -1
# Video Games                                 4052    30.8    15984
# Wholesale                                    729    10.8     5851
#
# [63 rows x 3 columns]

# %%
#What is this? should we drop it from our DF?
df1.groupby('Unnamed: 0').sum()
# Out:
#             Rating  Founded
# Unnamed: 0
# 0              3.8     1973
# 1              3.4     1984
# 2              4.8     2010
# 3              3.8     1965
# 4              2.9     1998
# ...            ...      ...
# 951            4.4     2006
# 952            2.6     1984
# 953            3.2       -1
# 954            4.8     2015
# 955            3.6     1967
#
# [956 rows x 2 columns]
