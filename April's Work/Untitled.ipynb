# %%
import pandas as pd
import numpy as np

# %%
file = "salary.csv"
df = pd.read_csv(file)
df.head()
# Out:
#                    Job Title                               Job Title.1  \
# 0             Data Scientist                            Data Scientist
# 1             Data Scientist           Senior Scientist - Neuroscience
# 2  Machine Learning Engineer  Senior Data & Machine Learning Scientist
# 3             Data Scientist           Senior Scientist - Neuroscience
# 4  Machine Learning Engineer  Senior Data & Machine Learning Scientist
#
#                                      Job Description  Rating  \
# 0  Are you passionate about providing real impact...     4.5
# 1  Sunovion Pharmaceuticals is looking for a Seni...     3.5
# 2  Passionate about precision medicine and advanc...     3.0
# 3  Sunovion Pharmaceuticals is looking for a Seni...     3.5
# 4  Passionate about precision medicine and advanc...     3.0
#
#                                         Company Name         Location State  \
# 0  Johns Hopkins University Applied Physics Labor...       Laurel, MD    MD
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Job Title.1', 'Job Description', 'Rating', 'Company Name',
#        'Location', 'State', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'same_state', 'age', 'python_yn', 'R_yn',
#        'spark', 'aws', 'excel'],
#       dtype='object')

# %%
df1 = df.rename(columns={"Job Title": "job_title"})
df1.head()
# Out:
#                    job_title                               Job Title.1  \
# 0             Data Scientist                            Data Scientist
# 1             Data Scientist           Senior Scientist - Neuroscience
# 2  Machine Learning Engineer  Senior Data & Machine Learning Scientist
# 3             Data Scientist           Senior Scientist - Neuroscience
# 4  Machine Learning Engineer  Senior Data & Machine Learning Scientist
#
#                                      Job Description  Rating  \
# 0  Are you passionate about providing real impact...     4.5
# 1  Sunovion Pharmaceuticals is looking for a Seni...     3.5
# 2  Passionate about precision medicine and advanc...     3.0
# 3  Sunovion Pharmaceuticals is looking for a Seni...     3.5
# 4  Passionate about precision medicine and advanc...     3.0
#
#                                         Company Name         Location State  \
# 0  Johns Hopkins University Applied Physics Labor...       Laurel, MD    MD
# ...

# %%
df2=df1[["job_title", "Industry","avg_salary","job_state","python_yn", "R_yn", "aws", "excel"]]
df2.head()
# Out:
#                    job_title                   Industry  avg_salary job_state  \
# 0             Data Scientist        Aerospace & Defense       130.0        MD
# 1             Data Scientist  Biotech & Pharmaceuticals       145.0        MA
# 2  Machine Learning Engineer  Biotech & Pharmaceuticals       133.0        IL
# 3             Data Scientist  Biotech & Pharmaceuticals       145.0        MA
# 4  Machine Learning Engineer  Biotech & Pharmaceuticals       133.0        IL
#
#    python_yn  R_yn  aws  excel
# 0          1     0    0      1
# 1          1     0    0      1
# 2          1     0    1      0
# 3          1     0    0      1
# 4          1     0    1      0

# %%
df3=df1[["job_title"]]
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 704 entries, 0 to 703
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   job_title  704 non-null    object
# dtypes: object(1)
# memory usage: 5.6+ KB

# %%
df4=df3.drop_duplicates(subset=["job_title"], ignore_index=True)
df4
# Out:
#                    job_title
# 0             Data Scientist
# 1  Machine Learning Engineer
# 2              Data Engineer
# 3               Data Analyst

# %%
df2.to_csv(r'glass.csv', index=False)

# %%
df4.to_csv(r'job_title.csv', index=False)
