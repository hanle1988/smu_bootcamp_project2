# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - Downloading: 100%|████████████████████████████████████████████████████████| 6.58M/6.58M [00:02<00:00, 3.28MB/s]

# %%
url = "https://www.dice.com/jobs?q=data%20scientist&countryCode=US&radius=30&radiusUnit=mi&page=1&pageSize=20&language=en&eid=S2Q_,bw_1"
# reponse = requests.get(url)
# reponse.status_code
browser.visit(url)

# %%
html = browser.html
html[0:500]
# Out:
# '<html lang="en" xmlns:ng="http://angularjs.org" class=""><head><style type="text/css">@charset "UTF-8";[ng\\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide{display:none !important;}ng\\:form{display:block;}</style>\n    \n\n\n\n    <style>.async-hide { opacity: 0 !important} </style>\n<script src="//bat.bing.com/bat.js" async=""></script><script src="https://connect.facebook.net/signals/config/412179360593168?v=2.9.90&amp;r=stable" async=""></script><script async="" src="h'

# %%
dice_soup= BeautifulSoup(html,'lxml')
type(dice_soup)
# Out:
# bs4.BeautifulSoup

# %%
# listjob= dice.find_all("div _ngcontent-npt-c100",{"class":"ng-star-inserted"})

listjobs= dice_soup.find_all("div",{"class":"ng-star-inserted"})
len(listjobs)
# Out:
# 66

# %%
listjob = listjobs[7]
listjob
# Out:
# <div _ngcontent-ppa-c103="" class="ng-star-inserted" data-cy="search-display-section" id="searchDisplay-div"><div _ngcontent-ppa-c103="" aria-level="2" class="sr-only" role="heading">Job Search Results</div><!-- --><div _ngcontent-ppa-c103="" class="col-lg-12 form-group no-padding ng-star-inserted"><dhi-search-alerts-widget _ngcontent-ppa-c103="" _nghost-ppa-c85=""><dhi-search-alert _ngcontent-ppa-c85="" _nghost-ppa-c84=""><div _ngcontent-ppa-c84="" data-cy="search-alert-container" id="searchAlert-div"><form _ngcontent-ppa-c84="" class="ng-untouched ng-pristine ng-invalid" novalidate=""><div _ngcontent-ppa-c84="" class="job-alert-element"><!-- --><!-- --><!-- --><div _ngcontent-ppa-c84="" class="w-100 ng-star-inserted"><div _ngcontent-ppa-c84="" class="d-md-none d-xl-block job-alert-bell bg-secondary"><i _ngcontent-ppa-c84="" class="fa fa-bell-o"></i></div><div _ngcontent-ppa-c84="" class="w-100"><div _ngcontent-ppa-c84="" class="row"><div _ngcontent-ppa-c84="" class="col-10 col-md-5
# ...
